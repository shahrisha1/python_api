# %%
#locally install library
# !pip install citipy
# !pip install unidecode
# Out:
# Requirement already satisfied: citipy in /Users/risha/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: kdtree>=0.12 in /Users/risha/anaconda3/lib/python3.6/site-packages (from citipy)
# Requirement already satisfied: unidecode in /Users/risha/anaconda3/lib/python3.6/site-packages

# %%
#import dependencies
from citipy import citipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from citipy import citipy
import requests as req
import unidecode
import time
from math import sqrt
from datetime import datetime

# %%
# Save config information
wkey = "1ec6103365f2368a1efafa7452ebb15f"
url = "http://api.openweathermap.org/data/2.5/weather?"
gkey = "AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8"

# %%
#data frame of randomly generated lat and long
location_data = pd.DataFrame()
location_data['rand_lat'] = [np.random.uniform(-90,90) for x in range(1500)]
location_data['rand_lng'] = [np.random.uniform(-180, 180) for x in range(1500)]

#add closest city and country column
location_data['closest_city'] = ""
location_data['country'] = ""

#find and add closest city and country code
for index, row in location_data.iterrows():
    lat = row['rand_lat']
    lng = row['rand_lng']
    location_data.set_value(index, 'closest_city', citipy.nearest_city(lat, lng).city_name)
    location_data.set_value(index, 'country', citipy.nearest_city(lat, lng).country_code)

# %%
# delete repeated cities and find unique city count
location_data = location_data.drop_duplicates(['closest_city', 'country'])
location_data = location_data.dropna()
len(location_data['closest_city'].value_counts())
# Out:
# 632

# %%
# keep only city and country
# random lats and lngs no longer needed
location_data = location_data[['closest_city', 'country']]

#rename columnds for later merging
location_data = location_data.rename(columns = {'closest_city': 'city'})

# %%
# read in open weather map's country Id json
api_city_data = pd.read_json('city.list.json')

for index, row in api_city_data.iterrows():
    lower_city = row['name'].lower() 
    unaccented = unidecode.unidecode(lower_city) 
    lower_country = row['country'].lower() 
    api_city_data.set_value(index, 'name', unaccented) 
    api_city_data.set_value(index, 'country', lower_country) 
    
api_city_data = api_city_data.rename(columns = {'name': 'city'}) # rename for merge

# %%
#merge with random cities from location_data
merged_df = location_data.merge(api_city_data, how = 'left', on = ('city', 'country'))
merged_df = merged_df.drop_duplicates(['city', 'country'])
merged_df.head()
# Out:
#          city country                                    coord         id
# 0  chokurdakh      ru    {'lon': 147.916672, 'lat': 70.633331}  2126123.0
# 1     rikitea      pf  {'lon': -134.969177, 'lat': -23.120279}  4030556.0
# 2       kapaa      us   {'lon': -159.318954, 'lat': 22.075211}  5848280.0
# 3      beloha      mg     {'lon': 45.049999, 'lat': -25.16667}  1067565.0
# 4      albany      au     {'lon': 118.123451, 'lat': -34.7099}  7839657.0

# %%
#clean-up
merged_df['coord'] = merged_df['coord'].fillna('') 
merged_df['id'] = merged_df['id'].fillna(0) 
merged_df['id'] = merged_df['id'].astype(dtype = 'int64') 
merged_df['id'].dtype
# Out:
# dtype('int64')

# %%
# check which countries did not find ids
no_id = merged_df[merged_df['id'] == 0]
no_id.head()
# Out:
#               city country coord  id
# 13       taolanaro      mg         0
# 19      kaitangata      nz         0
# 32  howard springs      au         0
# 37            asfi      ma         0
# 38    attawapiskat      ca         0

# %%
#check how many without ids
len(no_id)
# Out:
# 99

# %%
#use google api to find missing values
g_url = 'https://maps.googleapis.com/maps/api/geocode/json?address='

counter = 0 #for check of all cities
for index,row in merged_df.iterrows():
    if row['id'] == 0:
        city = row['city']
        country = row['country']
        print('Now retrieving coordinates for city #%s: %s, %s' %(index, city, country))
        target_url = '%s%s,+%s&key=%s' % (g_url, city, country, gkey)
        print(target_url)
        try:
            response = req.get(target_url).json()
            response_path = response['results'][0]['geometry']['location']
            merged_df.set_value(index, 'coord', {'lon': response_path['lng'], 'lat': response_path['lat']})
        except:
            print('Missing Data for city #%s: %s,%s' %(index, city, country))
        counter += 1
#     if counter == 10:
#             break

print(counter) #to check for same number of records as no_id
# Out:
# Now retrieving coordinates for city #13: taolanaro, mg
# https://maps.googleapis.com/maps/api/geocode/json?address=taolanaro,+mg&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #19: kaitangata, nz
# https://maps.googleapis.com/maps/api/geocode/json?address=kaitangata,+nz&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #32: howard springs, au
# https://maps.googleapis.com/maps/api/geocode/json?address=howard springs,+au&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #37: asfi, ma
# https://maps.googleapis.com/maps/api/geocode/json?address=asfi,+ma&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #38: attawapiskat, ca
# https://maps.googleapis.com/maps/api/geocode/json?address=attawapiskat,+ca&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #46: barentsburg, sj
# https://maps.googleapis.com/maps/api/geocode/json?address=barentsburg,+sj&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #50: samalaeulu, ws
# https://maps.googleapis.com/maps/api/geocode/json?address=samalaeulu,+ws&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #51: lasa, cn
# https://maps.googleapis.com/maps/api/geocode/json?address=lasa,+cn&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #53: belushya guba, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=belushya guba,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #78: mataura, pf
# https://maps.googleapis.com/maps/api/geocode/json?address=mataura,+pf&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Missing Data for city #78: mataura,pf
# Now retrieving coordinates for city #83: saleaula, ws
# https://maps.googleapis.com/maps/api/geocode/json?address=saleaula,+ws&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #94: kayerkan, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=kayerkan,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #100: amderma, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=amderma,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #112: labutta, mm
# https://maps.googleapis.com/maps/api/geocode/json?address=labutta,+mm&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #143: nikolskoye, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=nikolskoye,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #147: kapoeta, sd
# https://maps.googleapis.com/maps/api/geocode/json?address=kapoeta,+sd&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #158: henties bay, na
# https://maps.googleapis.com/maps/api/geocode/json?address=henties bay,+na&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #166: nizhneyansk, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=nizhneyansk,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #167: lethem, gy
# https://maps.googleapis.com/maps/api/geocode/json?address=lethem,+gy&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #168: sentyabrskiy, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=sentyabrskiy,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Missing Data for city #168: sentyabrskiy,ru
# Now retrieving coordinates for city #181: palabuhanratu, id
# https://maps.googleapis.com/maps/api/geocode/json?address=palabuhanratu,+id&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #182: bolungarvik, is
# https://maps.googleapis.com/maps/api/geocode/json?address=bolungarvik,+is&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #189: tsentralnyy, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=tsentralnyy,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Missing Data for city #189: tsentralnyy,ru
# Now retrieving coordinates for city #190: codrington, ag
# https://maps.googleapis.com/maps/api/geocode/json?address=codrington,+ag&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #192: tarhunah, ly
# https://maps.googleapis.com/maps/api/geocode/json?address=tarhunah,+ly&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #199: vila, vu
# https://maps.googleapis.com/maps/api/geocode/json?address=vila,+vu&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #204: zimatlan, mx
# https://maps.googleapis.com/maps/api/geocode/json?address=zimatlan,+mx&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #212: kismayo, so
# https://maps.googleapis.com/maps/api/geocode/json?address=kismayo,+so&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #213: raudeberg, no
# https://maps.googleapis.com/maps/api/geocode/json?address=raudeberg,+no&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #218: kuche, cn
# https://maps.googleapis.com/maps/api/geocode/json?address=kuche,+cn&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #224: biak, id
# https://maps.googleapis.com/maps/api/geocode/json?address=biak,+id&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #243: faya, td
# https://maps.googleapis.com/maps/api/geocode/json?address=faya,+td&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #247: airai, pw
# https://maps.googleapis.com/maps/api/geocode/json?address=airai,+pw&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #252: marcona, pe
# https://maps.googleapis.com/maps/api/geocode/json?address=marcona,+pe&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #256: umzimvubu, za
# https://maps.googleapis.com/maps/api/geocode/json?address=umzimvubu,+za&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #261: gat, ly
# https://maps.googleapis.com/maps/api/geocode/json?address=gat,+ly&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #276: bolshaya irba, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=bolshaya irba,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #277: grand centre, ca
# https://maps.googleapis.com/maps/api/geocode/json?address=grand centre,+ca&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #287: japura, br
# https://maps.googleapis.com/maps/api/geocode/json?address=japura,+br&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #293: louisbourg, ca
# https://maps.googleapis.com/maps/api/geocode/json?address=louisbourg,+ca&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #297: toliary, mg
# https://maps.googleapis.com/maps/api/geocode/json?address=toliary,+mg&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #298: illoqqortoormiut, gl
# https://maps.googleapis.com/maps/api/geocode/json?address=illoqqortoormiut,+gl&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #299: jalu, ly
# https://maps.googleapis.com/maps/api/geocode/json?address=jalu,+ly&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #324: tukrah, ly
# https://maps.googleapis.com/maps/api/geocode/json?address=tukrah,+ly&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #329: khani, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=khani,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #332: tsihombe, mg
# https://maps.googleapis.com/maps/api/geocode/json?address=tsihombe,+mg&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #345: senno, by
# https://maps.googleapis.com/maps/api/geocode/json?address=senno,+by&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #364: senmonorom, kh
# https://maps.googleapis.com/maps/api/geocode/json?address=senmonorom,+kh&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #366: rawannawi, ki
# https://maps.googleapis.com/maps/api/geocode/json?address=rawannawi,+ki&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #375: mogochin, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=mogochin,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #383: qui nhon, vn
# https://maps.googleapis.com/maps/api/geocode/json?address=qui nhon,+vn&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #388: san joaquin, bo
# https://maps.googleapis.com/maps/api/geocode/json?address=san joaquin,+bo&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Missing Data for city #388: san joaquin,bo
# Now retrieving coordinates for city #404: moose factory, ca
# https://maps.googleapis.com/maps/api/geocode/json?address=moose factory,+ca&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #416: shchelyayur, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=shchelyayur,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #439: cumaribo, co
# https://maps.googleapis.com/maps/api/geocode/json?address=cumaribo,+co&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #444: vaitupu, wf
# https://maps.googleapis.com/maps/api/geocode/json?address=vaitupu,+wf&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #448: falealupo, ws
# https://maps.googleapis.com/maps/api/geocode/json?address=falealupo,+ws&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #449: markova, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=markova,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Missing Data for city #449: markova,ru
# Now retrieving coordinates for city #455: avera, pf
# https://maps.googleapis.com/maps/api/geocode/json?address=avera,+pf&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Missing Data for city #455: avera,pf
# Now retrieving coordinates for city #460: bandar-e torkaman, ir
# https://maps.googleapis.com/maps/api/geocode/json?address=bandar-e torkaman,+ir&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #472: jinchengjiang, cn
# https://maps.googleapis.com/maps/api/geocode/json?address=jinchengjiang,+cn&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #482: lata, sb
# https://maps.googleapis.com/maps/api/geocode/json?address=lata,+sb&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #489: bud, no
# https://maps.googleapis.com/maps/api/geocode/json?address=bud,+no&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #494: karaul, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=karaul,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #498: tarudant, ma
# https://maps.googleapis.com/maps/api/geocode/json?address=tarudant,+ma&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #505: khormuj, ir
# https://maps.googleapis.com/maps/api/geocode/json?address=khormuj,+ir&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #511: bargal, so
# https://maps.googleapis.com/maps/api/geocode/json?address=bargal,+so&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #521: kazalinsk, kz
# https://maps.googleapis.com/maps/api/geocode/json?address=kazalinsk,+kz&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #523: syracuse, it
# https://maps.googleapis.com/maps/api/geocode/json?address=syracuse,+it&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #529: mys shmidta, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=mys shmidta,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #533: tabiauea, ki
# https://maps.googleapis.com/maps/api/geocode/json?address=tabiauea,+ki&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #589: eldikan, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=eldikan,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #593: minudasht, ir
# https://maps.googleapis.com/maps/api/geocode/json?address=minudasht,+ir&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #594: saint anthony, ca
# https://maps.googleapis.com/maps/api/geocode/json?address=saint anthony,+ca&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #601: yanan, cn
# https://maps.googleapis.com/maps/api/geocode/json?address=yanan,+cn&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #606: wajid, so
# https://maps.googleapis.com/maps/api/geocode/json?address=wajid,+so&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Missing Data for city #606: wajid,so
# Now retrieving coordinates for city #614: haibowan, cn
# https://maps.googleapis.com/maps/api/geocode/json?address=haibowan,+cn&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #616: grand river south east, mu
# https://maps.googleapis.com/maps/api/geocode/json?address=grand river south east,+mu&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #623: erenhot, cn
# https://maps.googleapis.com/maps/api/geocode/json?address=erenhot,+cn&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #627: itarema, br
# https://maps.googleapis.com/maps/api/geocode/json?address=itarema,+br&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #636: kawana waters, au
# https://maps.googleapis.com/maps/api/geocode/json?address=kawana waters,+au&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Missing Data for city #636: kawana waters,au
# Now retrieving coordinates for city #642: nam tha, la
# https://maps.googleapis.com/maps/api/geocode/json?address=nam tha,+la&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #645: salani, ws
# https://maps.googleapis.com/maps/api/geocode/json?address=salani,+ws&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #647: urumqi, cn
# https://maps.googleapis.com/maps/api/geocode/json?address=urumqi,+cn&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #652: pundaguitan, ph
# https://maps.googleapis.com/maps/api/geocode/json?address=pundaguitan,+ph&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #654: sobolevo, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=sobolevo,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #663: kambam, in
# https://maps.googleapis.com/maps/api/geocode/json?address=kambam,+in&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #665: chagda, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=chagda,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #671: gorkovskiy, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=gorkovskiy,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #685: lingao, cn
# https://maps.googleapis.com/maps/api/geocode/json?address=lingao,+cn&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #686: tumannyy, ru
# https://maps.googleapis.com/maps/api/geocode/json?address=tumannyy,+ru&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #698: chabahar, ir
# https://maps.googleapis.com/maps/api/geocode/json?address=chabahar,+ir&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #699: rungata, ki
# https://maps.googleapis.com/maps/api/geocode/json?address=rungata,+ki&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #701: ijaki, ki
# https://maps.googleapis.com/maps/api/geocode/json?address=ijaki,+ki&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #703: hurghada, eg
# https://maps.googleapis.com/maps/api/geocode/json?address=hurghada,+eg&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #729: hihifo, to
# https://maps.googleapis.com/maps/api/geocode/json?address=hihifo,+to&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #733: acapulco, mx
# https://maps.googleapis.com/maps/api/geocode/json?address=acapulco,+mx&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #741: kawhia, nz
# https://maps.googleapis.com/maps/api/geocode/json?address=kawhia,+nz&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# Now retrieving coordinates for city #752: yirol, sd
# https://maps.googleapis.com/maps/api/geocode/json?address=yirol,+sd&key=AIzaSyDK92V21lD1k-EbVVOxx5QHIkuWYn_91l8
# 99

# %%
#preview merged_df
merged_df.head(30)
# Out:
#                  city country                                    coord  \
# 0          chokurdakh      ru    {'lon': 147.916672, 'lat': 70.633331}
# 1             rikitea      pf  {'lon': -134.969177, 'lat': -23.120279}
# 2               kapaa      us   {'lon': -159.318954, 'lat': 22.075211}
# 3              beloha      mg     {'lon': 45.049999, 'lat': -25.16667}
# 4              albany      au     {'lon': 118.123451, 'lat': -34.7099}
# 6              hobart      au    {'lon': 147.329407, 'lat': -42.87936}
# 8             ushuaia      ar   {'lon': -68.300003, 'lat': -54.799999}
# 9               seoul      kr     {'lon': 126.977829, 'lat': 37.56826}
# 10             dikson      ru     {'lon': 80.546387, 'lat': 73.506943}
# 11             atuona      pf        {'lon': -139.033325, 'lat': -9.8}
# 12      batagay-alyta      ru     {'lon': 130.411392, 'lat': 67.80056}
# 13          taolanaro      mg  {'lon': 46.9853688, 'lat': -25.0225309}
# 14          busselton      au   {'lon': 115.370796, 'lat': -33.684769}
# 16          tuatapere      nz   {'lon': 167.683334, 'lat': -46.133331}
# 17             castro      cl   {'lon': -73.773193, 'lat': -42.472099}
# 18  santiago de chuco      pe        {'lon': -78.183327, 'lat': -8.15}
# 19         kaitangata      nz   {'lon': 169.8470967, 'lat': -46.28334}
# 20           red wing      us    {'lon': -92.533798, 'lat': 44.562469}
# 21          jamestown      sh      {'lon': -5.71675, 'lat': -15.93872}
# 22             jieshi      cn    {'lon': 115.825737, 'lat': 22.813379}
# 23               hilo      us   {'lon': -155.089996, 'lat': 19.729719}
# 24            waipawa      nz    {'lon': 175.515274, 'lat': -41.41222}
# 25              bluff      nz   {'lon': 168.333328, 'lat': -46.599998}
# 26           carupano      ve     {'lon': -63.258492, 'lat': 10.66781}
# 27           cidreira      br    {'lon': -50.205559, 'lat': -30.18111}
# 28        yellowknife      ca   {'lon': -114.352547, 'lat': 62.456001}
# 29                sur      om     {'lon': 59.528889, 'lat': 22.566669}
# 30       punta arenas      cl   {'lon': -70.916672, 'lat': -53.150002}
# 31            ardakan      ir     {'lon': 54.017471, 'lat': 32.310009}
# 32     howard springs      au   {'lon': 131.053056, 'lat': -12.492222}
#
#          id
# 0   2126123
# 1   4030556
# 2   5848280
# 3   1067565
# 4   7839657
# 6   2163355
# 8   3833367
# 9   1835848
# 10  1507390
# 11  4020109
# 12  2027042
# 13        0
# 14  7839477
# 16  2180815
# 17  3896218
# 18  3692072
# 19        0
# 20  5042773
# 21  3370903
# 22  1805857
# 23  5855927
# 24  2206874
# 25  2206939
# 26  3646382
# 27  3466165
# 28  6185377
# 29   286245
# 30  3874787
# 31   143073
# 32        0

# %%
#check to see how many records with no coordinates
no_coord = merged_df[merged_df['coord'] == ""]
no_coord
# Out:
#               city country coord  id
# 78         mataura      pf         0
# 168   sentyabrskiy      ru         0
# 189    tsentralnyy      ru         0
# 388    san joaquin      bo         0
# 449        markova      ru         0
# 455          avera      pf         0
# 606          wajid      so         0
# 636  kawana waters      au         0

# %%
#leave merged_df the same from here on
weather_data = merged_df.copy()

# %%
#preview weather_data to check for success
weather_data.head()
# Out:
#          city country                                    coord       id
# 0  chokurdakh      ru    {'lon': 147.916672, 'lat': 70.633331}  2126123
# 1     rikitea      pf  {'lon': -134.969177, 'lat': -23.120279}  4030556
# 2       kapaa      us   {'lon': -159.318954, 'lat': 22.075211}  5848280
# 3      beloha      mg     {'lon': 45.049999, 'lat': -25.16667}  1067565
# 4      albany      au     {'lon': 118.123451, 'lat': -34.7099}  7839657

# %%
counter = 0 
cur_err_list = [] 
for_err_list = [] 
cur_errors = 0  
for_errors = 0 

#create additional columns for open weather map data

#make columnds for lat and lng from open weather source
weather_data['lat'] = ""
weather_data['lng'] = ""

#make columns for current weather data (at time of pull)
weather_data['cur_date'] = ""
weather_data['cur_temp'] = ""
weather_data['cur_humidity'] = ""
weather_data['cur_clouds'] = ""
weather_data['cur_wind'] = ""

# make columns for records corresponding to the highest temperature 
# forecasted in the next 24 hours (from time of pull)
weather_data['max_date'] = ""
weather_data['max_temp'] = ""
weather_data['max_temp_humidity'] = ""
weather_data['max_temp_clouds'] = ""
weather_data['max_temp_wind'] = ""

# make columns for records corresponding to the average values
# forecasted in the next 5 days (from time of pull)
weather_data['avg_date0'] = ""
weather_data['avg_date1'] = ""
weather_data['avg_temp'] = ""
weather_data['avg_humidity'] = ""
weather_data['avg_clouds'] = ""
weather_data['avg_wind'] = ""

t0 = time.time() #for pause timer
for index, row in weather_data.iterrows():
    print('Now retrieving data for city #%s: %s, %s' % (index, row['city'], row['country']))
    if ((row['id']) == 0) and (row['coord'] != ""): 
        lat = row['coord']['lat']
        lon = row['coord']['lon']
        cur_url = 'https://api.openweathermap.org/data/2.5/weather?lat=%s&lon=%s&APPID=%s&units=imperial' % (lat, lon, wkey)  
        for_url = 'https://api.openweathermap.org/data/2.5/forecast?lat=%s&lon=%s&APPID=%s&units=imperial' % (lat, lon, wkey)  
    elif row['id'] != 0: 
        loc_id = row['id']
        cur_url = 'https://api.openweathermap.org/data/2.5/weather?id=%s&APPID=%s&units=imperial' % (loc_id, wkey)
        for_url = 'https://api.openweathermap.org/data/2.5/forecast?id=%s&APPID=%s&units=imperial' % (loc_id, wkey)
    else: 
        city = row['city']
        country = row['country']
        cur_url = 'https://api.openweathermap.org/data/2.5/weather?q=%s,%s&APPID=%s&units=imperial' % (city, country, wkey)
        for_url = 'https://api.openweathermap.org/data/2.5/forecast?q=%s,%s&APPID=%s&units=imperial' % (city, country, wkey)
    print('Current Weather URL:')
    print(cur_url)
    print('Forecast Weather URL:')
    print(for_url)
    #get current weather data
    try:
        cur_response = req.get(cur_url).json()
        weather_data.set_value(index, 'lat', cur_response['coord']['lat'])
        weather_data.set_value(index, 'lng', cur_response['coord']['lon'])
        weather_data.set_value(index, 'cur_date', cur_response['dt'])
        weather_data.set_value(index, 'cur_temp', cur_response['main']['temp'])
        weather_data.set_value(index, 'cur_humidity', cur_response['main']['humidity'])
        weather_data.set_value(index, 'cur_clouds', cur_response['clouds']['all'])
        weather_data.set_value(index, 'cur_wind', cur_response['wind']['speed'])
    except:
        print('Missing Current Weather Info for city #%s: %s, %s' % (index, row['city'], row['country']))
        cur_err_list.append(index)
        cur_errors += 1
    try:
        #get max temperature weather data
        for_response = req.get(for_url).json()
        for_path = for_response['list']
        temps_24h = [] 
        for n in range(9):
            temps_24h.append(for_path[n]['main']['temp_max'])
        max_index = temps_24h.index(max(temps_24h))
        weather_data.set_value(index, 'max_date', for_path[max_index]['dt'])
        weather_data.set_value(index, 'max_temp', for_path[max_index]['main']['temp_max'])
        weather_data.set_value(index, 'max_temp_humidity', for_path[max_index]['main']['humidity'])
        weather_data.set_value(index, 'max_temp_clouds', for_path[max_index]['clouds']['all'])
        weather_data.set_value(index, 'max_temp_wind', for_path[max_index]['wind']['speed'])
        # get avg forecast values 
        dat = []
        tem = []
        clo = []
        win = []
        hum = []
        for n in for_path:
            dat.append(n['dt'])
            tem.append(n['main']['temp'])
            clo.append(n['clouds']['all'])
            win.append(n['wind']['speed'])
            hum.append(n['main']['humidity'])
        weather_data.set_value(index, 'avg_date0', dat[0])
        weather_data.set_value(index, 'avg_date1', dat[-1])
        weather_data.set_value(index, 'avg_temp', np.mean(tem))
        weather_data.set_value(index, 'avg_humidity', np.mean(hum)) 
        weather_data.set_value(index, 'avg_clouds', np.mean(clo)) 
        weather_data.set_value(index, 'avg_wind', np.mean(win)) 
    except:
        print('Missing Forecast Info for city #%s: %s, %s' % (index, row['city'], row['country']))
        for_err_list.append(index)
        for_errors += 1
    print('---------------------------------------------------------------------------')
    counter +=1
    if counter % 30 == 0: 
        t1 = time.time() 
        sl_time = 70 - (t1-t0) 
        print("")
        print('********Sleeping for %s seconds.********' % (sl_time))
        print("")
        time.sleep(sl_time) 
        t0 = time.time()
# Out:
# Now retrieving data for city #0: chokurdakh, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2126123&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2126123&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #1: rikitea, pf
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=4030556&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=4030556&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #2: kapaa, us
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=5848280&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=5848280&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #3: beloha, mg
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1067565&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1067565&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #4: albany, au
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=7839657&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=7839657&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #6: hobart, au
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2163355&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2163355&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #8: ushuaia, ar
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3833367&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3833367&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #9: seoul, kr
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1835848&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1835848&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #10: dikson, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1507390&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1507390&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #11: atuona, pf
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=4020109&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=4020109&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #12: batagay-alyta, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2027042&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2027042&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #13: taolanaro, mg
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=-25.0225309&lon=46.9853688&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=-25.0225309&lon=46.9853688&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #14: busselton, au
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=7839477&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=7839477&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #16: tuatapere, nz
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2180815&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2180815&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #17: castro, cl
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3896218&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3896218&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #18: santiago de chuco, pe
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3692072&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3692072&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #19: kaitangata, nz
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=-46.28334&lon=169.8470967&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=-46.28334&lon=169.8470967&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #20: red wing, us
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=5042773&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=5042773&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #21: jamestown, sh
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3370903&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3370903&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #22: jieshi, cn
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1805857&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1805857&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #23: hilo, us
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=5855927&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=5855927&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #24: waipawa, nz
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2206874&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2206874&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #25: bluff, nz
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2206939&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2206939&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #26: carupano, ve
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3646382&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3646382&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #27: cidreira, br
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3466165&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3466165&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #28: yellowknife, ca
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=6185377&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=6185377&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #29: sur, om
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=286245&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=286245&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #30: punta arenas, cl
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3874787&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3874787&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #31: ardakan, ir
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=143073&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=143073&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #32: howard springs, au
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=-12.492222&lon=131.053056&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=-12.492222&lon=131.053056&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
#
# ********Sleeping for 33.435128927230835 seconds.********
#
# Now retrieving data for city #33: tocopilla, cl
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3869716&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3869716&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #34: porto novo, cv
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3374336&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3374336&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #35: new norfolk, au
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2155415&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2155415&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #36: meulaboh, id
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1214488&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1214488&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #37: asfi, ma
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=32.3008151&lon=-9.2272033&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=32.3008151&lon=-9.2272033&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #38: attawapiskat, ca
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=52.9258846&lon=-82.42889219999999&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=52.9258846&lon=-82.42889219999999&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #39: neiafu, to
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=4032420&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=4032420&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #40: bakchar, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1511057&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1511057&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #41: salalah, om
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=286621&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=286621&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #42: afsin, tr
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=325304&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=325304&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #43: qaanaaq, gl
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3831208&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3831208&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #44: petropavlovsk-kamchatskiy, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2122104&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2122104&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #45: bagamer, hu
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=722738&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=722738&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #46: barentsburg, sj
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=78.0648475&lon=14.2334597&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=78.0648475&lon=14.2334597&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #47: kaka, tm
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=161901&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=161901&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #48: ancud, cl
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3899695&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3899695&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #49: tuktoyaktuk, ca
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=6170031&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=6170031&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #50: samalaeulu, ws
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=-13.4973599&lon=-172.3105939&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=-13.4973599&lon=-172.3105939&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #51: lasa, cn
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=29.652491&lon=91.17210999999999&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=29.652491&lon=91.17210999999999&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #52: vaini, to
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=4032243&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=4032243&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #53: belushya guba, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=71.54555599999999&lon=52.32027799999999&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=71.54555599999999&lon=52.32027799999999&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #54: saint-philippe, re
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=6690301&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=6690301&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #56: kutum, sd
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=371745&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=371745&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #57: pangkalanbuun, id
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1632694&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1632694&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #58: noumea, nc
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2139520&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2139520&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #60: quang ngai, vn
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1568770&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1568770&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #61: nelson bay, au
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2155562&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2155562&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #62: huarmey, pe
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3939168&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3939168&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #63: nazca, pe
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3934356&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3934356&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #64: pimenteiras, br
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3392095&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3392095&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
#
# ********Sleeping for 31.229498863220215 seconds.********
#
# Now retrieving data for city #65: bouca, cf
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2387890&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2387890&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #66: faanui, pf
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=4034551&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=4034551&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #67: katsuura, jp
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2112309&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2112309&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #68: port alfred, za
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=964432&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=964432&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #69: morant bay, jm
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3489440&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3489440&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #70: ulaanbaatar, mn
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2028462&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2028462&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #71: brae, gb
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2654970&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2654970&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #72: narasannapeta, in
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1261853&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1261853&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #73: evensk, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2125693&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2125693&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #74: dingle, ie
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2964782&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2964782&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #75: husavik, is
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2629833&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2629833&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #76: ust-nera, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2120048&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2120048&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #77: cape town, za
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3369157&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3369157&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #78: mataura, pf
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?q=mataura,pf&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?q=mataura,pf&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Missing Current Weather Info for city #78: mataura, pf
# Missing Forecast Info for city #78: mataura, pf
# ---------------------------------------------------------------------------
# Now retrieving data for city #79: rock springs, us
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=5836898&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=5836898&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #81: cherskiy, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2126199&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2126199&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #82: barrow, us
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=5880054&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=5880054&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #83: saleaula, ws
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=-13.4482906&lon=-172.3367114&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=-13.4482906&lon=-172.3367114&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #84: east london, za
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1006984&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1006984&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #85: ribeira grande, pt
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=8010689&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=8010689&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #87: pizhma, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=509176&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=509176&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #88: kavieng, pg
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2094342&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2094342&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #89: templin, de
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2823533&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2823533&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #90: ponta do sol, cv
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3374346&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3374346&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #91: nuuk, gl
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3421319&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3421319&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #92: pangai, to
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=4032369&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=4032369&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #93: hermanus, za
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3366880&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3366880&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #94: kayerkan, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=69.36666699999999&lon=87.733333&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=69.36666699999999&lon=87.733333&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #95: san cristobal, ec
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3651949&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3651949&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #96: makarska, hr
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3195890&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3195890&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
#
# ********Sleeping for 29.194724082946777 seconds.********
#
# Now retrieving data for city #97: severo-kurilsk, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2121385&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2121385&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #98: carballo, es
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=6357289&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=6357289&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #100: amderma, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=69.751221&lon=61.6636961&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=69.751221&lon=61.6636961&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #101: khatanga, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2022572&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2022572&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #102: margate, za
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=978895&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=978895&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #103: saskylakh, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2017155&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2017155&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #104: muros, es
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=6357322&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=6357322&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #106: palampur, in
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1260784&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1260784&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #107: chatra, in
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1274536&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1274536&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #108: natal, br
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3394023&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3394023&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #109: sayyan, ye
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=70979&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=70979&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #110: evans, us
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=4193699&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=4193699&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #112: labutta, mm
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=16.149328&lon=94.7562159&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=16.149328&lon=94.7562159&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #113: dosso, ne
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2445486&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2445486&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #115: dumas, us
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=4109226&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=4109226&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #117: leh, in
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1264976&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1264976&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #118: mar del plata, ar
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3430863&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3430863&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #119: galle, lk
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1246294&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1246294&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #120: businga, cd
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=217637&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=217637&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #121: isangel, vu
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2136825&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2136825&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #122: maryville, us
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=4639848&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=4639848&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #125: loandjili, cg
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2258378&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2258378&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #126: leningradskiy, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2123814&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2123814&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #127: pisco, pe
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3932145&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3932145&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #128: puerto ayora, ec
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3652764&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3652764&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #129: te anau, nz
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2181625&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2181625&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #130: kamyshin, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=553287&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=553287&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #131: behshahr, ir
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=140918&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=140918&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #132: eureka, us
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=5563397&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=5563397&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #138: nouadhibou, mr
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2377457&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2377457&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ...
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3580733&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3580733&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #709: tres arroyos, ar
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3833859&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3833859&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #710: christchurch, nz
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2192362&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2192362&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #711: sao geraldo do araguaia, br
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3388760&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3388760&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #712: noboribetsu, jp
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2128894&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2128894&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #713: aksarka, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1512019&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1512019&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #714: arlit, ne
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2447513&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2447513&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #715: nabire, id
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1634614&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1634614&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #716: lipin bor, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=535113&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=535113&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #717: cururupu, br
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3401148&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3401148&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
#
# ********Sleeping for 31.052659273147583 seconds.********
#
# Now retrieving data for city #718: maragogi, br
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3395458&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3395458&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #719: arak, ir
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=143127&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=143127&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #720: luanda, ao
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2240449&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2240449&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #721: el guayabito, hn
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3611699&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3611699&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #722: saint-pierre, mq
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3569907&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3569907&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #723: perelyub, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=511416&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=511416&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #724: fuerte olimpo, py
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3438102&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3438102&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #725: pueblo rico, co
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3671633&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3671633&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #726: fukue, jp
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1863997&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1863997&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #727: yenagoa, ng
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2318123&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2318123&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #728: voh, nc
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2137748&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2137748&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #729: hihifo, to
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=-15.9528061&lon=-173.7955818&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=-15.9528061&lon=-173.7955818&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #730: cabatuan, ph
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1721714&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1721714&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #733: acapulco, mx
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=16.8531086&lon=-99.8236533&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=16.8531086&lon=-99.8236533&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #734: haines junction, ca
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=5969025&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=5969025&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #735: vitim, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2013375&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2013375&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #737: sao jose dos campos, br
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=6322578&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=6322578&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #739: altea, es
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=6355394&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=6355394&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #741: kawhia, nz
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=-38.0684799&lon=174.815611&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=-38.0684799&lon=174.815611&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #742: intipuca, sv
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3585480&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3585480&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #743: namibe, ao
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3347019&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3347019&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #744: anadyr, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2127202&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2127202&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #745: ewo, cg
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=2260009&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=2260009&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #746: rawson, ar
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3839307&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3839307&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #747: pekan, my
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1734971&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1734971&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #748: letka, ru
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=535639&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=535639&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #749: mier, mx
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=3523222&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=3523222&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #750: morondava, mg
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1058381&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1058381&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #751: naze, jp
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?id=1855540&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?id=1855540&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
# Now retrieving data for city #752: yirol, sd
# Current Weather URL:
# https://api.openweathermap.org/data/2.5/weather?lat=6.5524518&lon=30.50236&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# Forecast Weather URL:
# https://api.openweathermap.org/data/2.5/forecast?lat=6.5524518&lon=30.50236&APPID=1ec6103365f2368a1efafa7452ebb15f&units=imperial
# ---------------------------------------------------------------------------
#
# ********Sleeping for 33.70006322860718 seconds.********

# %%
#view columns
weather_data.columns

# %%
# clean up
clean_col = weather_data.columns[4:]
clean_col

# %%
# #loop throught to clean columns to be able to use for graphs
# for c in clean_col:
#     weather_data[c] = pd.to_numeric(weather_data[c], errors = 'coerce') 
#     weather_data = weather_data[weather_data[c].isnull() == False]

# len(weather_data)

# %%
# check weather data types
weather_data.dtypes

# %%
#Export to csv
weather_data.to_csv('clean_weather_data.csv')

# %%
#date sorting and conversions dictionary for graph labels

dates = {'max_cur': weather_data['cur_date'].max(),
         'min_cur': weather_data['cur_date'].min(),
         'max_max': weather_data['max_date'].max(),
         'min_max': weather_data['max_date'].min(),
         'min_avg': weather_data['avg_date0'].max(),
         'max_avg': weather_data['avg_date1'].min()
        }

for key in dates.keys():
    convert = datetime.utcfromtimestamp(dates[key]).strftime('%Y-%m-%d%, %I:%M:%S %p')
    dates[key] = convert

# %%
# Temp vs Latitude Graphs
temp_list = ['cur_temp', 'max_temp', 'avg_temp']  #would have done only dict but wanted consistent order.

xvals = weather_data['lat']

for temp in temp_list:
    # y values of each item in list for separate graphs
    yvals = weather_data[temp]
    #adds title including title and timestamp range of sample data
    plt.title("%s vs Latitude \n Samples Taken from %s to %s UTC" % (labels_dic[temp], dates['min_' + temp.split('_')[0]],  dates['max_' + temp.split('_')[0]]))
    plt.axvline(0, color = 'black', alpha = .25, label = 'Equator') #adds equator line
    plt.text(1,30,'Equator',rotation=90)
    plt.ylim(15, 120) #to give consistent scale
    plt.xlabel('Latitude')
    plt.ylabel("Temperature (F)")
    plt.scatter(xvals, yvals)
    plt.show()
    plt.savefig("temp_latitude.png")

# %%
# Humidity vs Latitude Graphs
#see first set of graphs commenting for notes
hum_list = ['cur_humidity', 'max_temp_humidity', 'avg_humidity']  #would have done only dict but wanted consistent order.

xvals = weather_data['lat']

for hum in hum_list:
    yvals = weather_data[hum]
    plt.title("%s vs Latitude \n Samples Taken from %s to %s UTC" % (labels_dic[hum], dates['min_' + hum.split('_')[0]],  dates['max_' + hum.split('_')[0]]))
    plt.xlabel('Latitude')
    plt.ylabel('Humidity (%)')
    plt.axvline(0, color = 'black', alpha = .25, label = 'Equator')
    plt.text(1,20,'Equator',rotation=90)
    plt.scatter(xvals, yvals)
    plt.show()
    plt.savefig("humidity_latitude.png" )

# %%
# Cloud Cover vs Latitude Graphs
#see first set of graphs commenting for notes
cloud_list = ['cur_clouds', 'max_temp_clouds', 'avg_clouds']  #would have done only dict but wanted consistent order.

xvals = weather_data['lat']

for clo in cloud_list:
    yvals = weather_data[clo]
    plt.title("%s vs Latitude \n Samples Taken from %s to %s UTC" % (labels_dic[clo], dates['min_' + clo.split('_')[0]],  dates['max_' + clo.split('_')[0]]))
    plt.xlabel('Latitude')
    plt.ylabel('Cloud Cover (%)')
    plt.ylim(-5,105)
    plt.axvline(0, color = 'black', alpha = .25, label = 'Equator')
    plt.text(-5,-20,'Equator')
    plt.scatter(xvals, yvals)
    plt.show()
    plt.savefig("cloudcover_latitude.png")

# %%
# Wind Speed vs Latitude Graphs
#see first set of graphs commenting for notes
win_list = ['cur_wind', 'max_temp_wind', 'avg_wind']  #would have done only dict but wanted consistent order.

xvals = weather_data['lat']

for win in win_list:
    yvals = weather_data[win]
    plt.title("%s vs Latitude \n Samples Taken from %s to %s UTC" % (labels_dic[win], dates['min_' + win.split('_')[0]],  dates['max_' + win.split('_')[0]]))
    plt.xlabel('Latitude')
    plt.ylabel('Wind Speed (mph))')
    plt.ylim(-5,60)
    plt.axvline(0, color = 'black', alpha = .25, label = 'Equator')
    plt.text(1,35,'Equator',rotation=90)
    plt.scatter(xvals, yvals)
    plt.show()
    plt.savefig("windspeed_latitude.png")
